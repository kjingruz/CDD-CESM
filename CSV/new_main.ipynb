# %%
# !python clean_image_names.py
# Out:
# Filenames normalization completed.

# %%
# !python preprocess.py
# Out:
# Columns in the dataframe: Index(['Image_name', 'Patient_ID', 'Side', 'Type', 'Age',
#        'Breast density (ACR)', 'BIRADS', 'Findings', 'View', 'Tags', 'Machine',
#        'Pathology Classification/ Follow up', 'Classification'],
#       dtype='object')
# Failed to load image: ../../data/images/.DS_S.jpg
# Skipping image: ../../data/images/.DS_S.jpg due to preprocessing failure
# [ WARN:0@80.156] global loadsave.cpp:248 findDecoder imread_('../../data/annotated_images/.DS_S.jpg'): can't open/read file: check file path/integrity
# Failed to load image: ../../data/images/.DS_S.jpg
# Tracked category counts: {'Benign': 572, 'Malignant': 650, 'Normal': 784}
# Failed to process 1 images.
# Failed images:
# ../../data/images/.DS_S.jpg
# Created annotations CSV at: ../../data/annotations.csv
# Updated annotations CSV with correct category IDs at: ../../data/annotations.csv
# Category counts:
#  category_id
# 2.0    755
# 1.0    661
# 0.0    585
# Name: count, dtype: int64
# ...

# %%
# !python classification_discrepancy.py
# Out:
# No discrepancies found.

# %%
import pandas as pd

# Load the annotations.csv file
file_path = '../../data/annotations.csv'
df = pd.read_csv(file_path)

# Count the number of 0s, 1s, and 2s in the category_id column
category_counts = df['category_id'].value_counts()

print(category_counts)
# Out:
# category_id
# 2.0    755
# 1.0    661
# 0.0    585
# Name: count, dtype: int64

# %%
# !python verify_file_structure.py
# Out:
# Columns in the dataframe: Index(['Image_name', 'Patient_ID', 'Side', 'Type', 'Age',
#        'Breast density (ACR)', 'BIRADS', 'Findings', 'View', 'Tags', 'Machine',
#        'Pathology Classification/ Follow up', 'Classification'],
#       dtype='object')
# Failed to load image: ../../data/images/.DS_S.jpg
# Skipping image: ../../data/images/.DS_S.jpg due to preprocessing failure
# [ WARN:0@97.291] global loadsave.cpp:248 findDecoder imread_('../../data/annotated_images/.DS_S.jpg'): can't open/read file: check file path/integrity
# Failed to load image: ../../data/images/.DS_S.jpg
# Tracked category counts: {'Benign': 0, 'Malignant': 0, 'Normal': 2006}
# Failed to process 1 images.
# Failed images:
# ../../data/images/.DS_S.jpg
# Created annotations CSV at: ../../data/annotations.csv
# No discrepancies found.
# Created directory: ../../data/train
# Created directory: ../../data/val
# Created directory: ../../data/test
# All classifications are verified.
# Copying training files...
# ...

# %%
# !python count_classification.py
# Out:
# [2024-06-17 22:59:18.705951 d2.data.build]: Distribution of instances among all 3 categories:
# |  Subset  |  category  | #instances   |
# |:--------:|:----------:|:-------------|
# |   Train  |   Benign   | 447          |
# |          | Malignant  | 488         |
# |          |   Normal   | 529         |
# |          |   total    | 1464         |
# |   Valid  |   Benign   | 55          |
# |          | Malignant  | 80         |
# |          |   Normal   | 103         |
# |          |   total    | 238         |
# |   Test   |   Benign   | 85          |
# |          | Malignant  | 94         |
# |          |   Normal   | 125         |
# |          |   total    | 304         |
# |  Overall |   Benign   | 587          |
# |          | Malignant  | 662         |
# |          |   Normal   | 757         |
# |          |   total    | 2006         |

# %%
# !python CSV_to_COCO.py
# Out:
# COCO JSON file saved at: /Users/kjingruz/Library/CloudStorage/OneDrive-McMasterUniversity/Research/Saha/data/train_annotations.json
# COCO JSON file saved at: /Users/kjingruz/Library/CloudStorage/OneDrive-McMasterUniversity/Research/Saha/data/valid_annotations.json
# COCO JSON file saved at: /Users/kjingruz/Library/CloudStorage/OneDrive-McMasterUniversity/Research/Saha/data/test_annotations.json

# %%
# !python train_lowtime.py
# Out:
# [06/18 16:11:57 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
# ...

# %%
# !python test.py
# Out:
# Annotations JSON path: /Users/kjingruz/Library/CloudStorage/OneDrive-McMasterUniversity/Research/Saha/data/test_annotations.json
# Test image directory path: /Users/kjingruz/Library/CloudStorage/OneDrive-McMasterUniversity/Research/Saha/data/test
# COCO Evaluator instantiated using config, this is deprecated behavior. Please pass in explicit arguments instead.
# Using previously cached COCO format annotations at './output/my_dataset_test_coco_format.json'. You need to clear the cache file if your dataset has been modified.
# /opt/anaconda3/lib/python3.11/site-packages/torch/functional.py:512: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3588.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
