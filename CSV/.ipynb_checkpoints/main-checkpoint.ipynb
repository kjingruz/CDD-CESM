# %%
# !python preprocess.py
# Out:
# Tracked category counts: {'Benign': 572, 'Malignant': 650, 'Normal': 784}
# Created annotations CSV at: ../../data/annotations.csv

# %%
# !python verify_file_structure.py
# Out:
# Created directory: ../../data/train
# Created directory: ../../data/valid
# Copied ../../data/images/P264_L_CM_CC.jpg to ../../data/train/P264_L_CM_CC.jpg
# Copied ../../data/images/P264_L_CM_MLO.jpg to ../../data/train/P264_L_CM_MLO.jpg
# Copied ../../data/images/P264_L_DM_CC.jpg to ../../data/train/P264_L_DM_CC.jpg
# Copied ../../data/images/P264_L_DM_MLO.jpg to ../../data/train/P264_L_DM_MLO.jpg
# Copied ../../data/images/P264_R_CM_CC.jpg to ../../data/train/P264_R_CM_CC.jpg
# Copied ../../data/images/P264_R_DM_CC.jpg to ../../data/train/P264_R_DM_CC.jpg
# Copied ../../data/images/P264_R_DM_MLO.jpg to ../../data/train/P264_R_DM_MLO.jpg
# Copied ../../data/images/P264_R_CM_MLO.jpg to ../../data/train/P264_R_CM_MLO.jpg
# Copied ../../data/images/P114_R_CM_CC.jpg to ../../data/train/P114_R_CM_CC.jpg
# Copied ../../data/images/P114_L_CM_CC.jpg to ../../data/train/P114_L_CM_CC.jpg
# Copied ../../data/images/P114_R_DM_CC.jpg to ../../data/train/P114_R_DM_CC.jpg
# ...

# %%
# !python train.py
# Out:
# [06/14 00:08:28 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
# ...
